# %%
# 各个api测试

import requests

base_url = "http://localhost:5000/"

response = requests.get(base_url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="https://unpkg.com/mvp.css@1.10.2/mvp.css">
#     <title>Login</title>
# </head>
#
# <body>
#     <main>
#         <section>
#             <form action="/u/login"  method="post">
#                 <header>
#                     <h1>SecCloud Login</h1>
#                 </header>
#                 <label for="input1">Username:</label>
#                 <input type="text" id="name" name="username" size="20" placeholder="User">
#                 <label for="textarea1">Password:</label>
#                 <input type="text" id="password" name="password" size="20" placeholder="********">
#                 <center>
#                     <p></p>
#                     <button type="submit">Submit</button>
#                 </center>
#             </form>
#         </section>
#     </main>
# </body>
#
# </html>

# %%
# admin 登录

url = base_url + "u/login"
data = {
    "username": "admin",
    "password": "admin"
}

current_session = requests.Session()
response = current_session.post(url, data=data)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <link href="https://lf3-cdn-tos.bytecdntp.com/cdn/expire-1-M/mdui/1.0.2/css/mdui.css" type="text/css"
#     rel="stylesheet" />
#   <link href="/static/dashboard.css" type="text/css">
#   <title>SecCloud</title>
# </head>
#
# <body class="mdui-appbar-with-toolbar mdui-drawer-body-left mdui-theme-accent-indigo">
#
#   <header class="mdui-appbar mdui-appbar-fixed mdui-color-white mdui-appbar-inset mdui-shadow-1">
#     <div class="mdui-toolbar">
#       <button class="mdui-btn mdui-btn-icon" mdui-drawer="{target: '#left-drawer'}">
#         <i class="mdui-icon material-icons">format_list_bulleted</i>
#       </button>
#       <i class="mdui-icon material-icons mdui-text-color-orange-500 mdui-color-white">dashboard</i>
#       <a href="/u/dashboard" class="mdui-typo-headline">DashBoard</a>
#       <div class="mdui-toolbar-spacer"></div>
#       <a href="/u/dashboard" class="mdui-btn mdui-btn-icon">
#         <i class="mdui-icon material-icons">refresh</i>
#       </a>
#       <button href="javascript:;" class="mdui-btn mdui-btn-icon" mdui-menu="{target: '#example-attr'}">
#         <i class="mdui-icon material-icons">more_vert</i>
#       </button>
#       <ul class="mdui-menu" id="example-attr">
#         <li class="mdui-menu-item">
#           <a href="/u/dashboard" class="mdui-ripple">Refresh</a>
#         </li>
#         <li class="mdui-menu-item">
#           <a href="javascript:;">Help & feedback</a>
#         </li>
#         <li class="mdui-divider"></li>
#         <li class="mdui-menu-item">
#           <a href="/u/logout" class="mdui-ripple">Sign out</a>
#         </li>
#       </ul>
#     </div>
#   </header>
#
#
#   <div class="mdui-drawer mdui-shadow-1 mdui-drawer-full-height" id="left-drawer">
#     <div class="mdui-list">
#       <li class="mdui-subheader mdui-color-indigo-50">
#         <i class="mdui-icon material-icons">check</i>
#         Finished
#       </li>
#
#       <!--<a href="#" class="mdui-list-item mdui-ripple mdui-text-color-indigo-500">
#         <i class="mdui-list-item-icon"></i>
#         APP.exe
#       </a>
#       <a href="#" class="mdui-list-item mdui-ripple mdui-text-color-indigo-500">
#         <i class="mdui-list-item-icon"></i>
#         nc.exe
#       </a>
#       <a href="#" class="mdui-list-item mdui-ripple mdui-text-color-indigo-500">
#         <i class="mdui-list-item-icon"></i>
#         ping.exe
#       </a>-->
#
# <a href="/e/report?id=1" class="mdui-list-item mdui-ripple mdui-text-color-indigo-500">
#         <i class="mdui-list-item-icon"></i>
#         demo
# </a>
#       <li class="mdui-subheader mdui-color-indigo-50">
#         <i class="mdui-icon material-icons">check_box_outline_blank</i>
#         <i class="mdui-list-item-icon"></i>
#         Unfinished
#       </li>
#       <!--<a href="#" class="mdui-list-item mdui-ripple mdui-text-color-indigo-500">
#         <i class="mdui-list-item-icon"></i>
#         python.exe
#       </a>-->
#
#     </div>
#   </div>
#
#   <main class="mdui-container">
#     <div class="mdui-row">
#       <div class="mdui-col-md-1 mdui-col-sm-2">
#       </div>
#       <div class="mdui-col-md-7 mdui-col-sm-8">
#         <div class="blank" style="height: 2rem;"></div>
#         <div class="mdui-typo-display-1" style="font-weight: 700;">Hello, admin.</div>
#         <div class="blank" style="height: 1rem;"></div>
#
#         <form class="mdui-row" action="/u/upload" method="post" enctype="multipart/form-data">
#           <div class="mdui-textfield mdui-textfield-floating-label mdui-col-sm-12">
#             <div class="mdui-typo-title" style="font-weight: 700;">Add new targets</div>
#             <label class="mdui-textfield-label">Program Name</label>
#             <input class="mdui-textfield-input" type="text" name="name" />
#             <label class="mdui-textfield-label">Arguments</label>
#             <input class="mdui-textfield-input" type="text" name="args" />
#           </div>
#           <input class="mdui-btn mdui-color-indigo file-input" type="file" name="file" style="display: none;">
#           <span class="mdui-btn mdui-btn-dense mdui-ripple mdui-color-indigo file-input-trigger">
#             <i class="mdui-icon material-icons ">attach_file</i>
#           </span>
#           <button class="mdui-btn mdui-btn-dense mdui-ripple mdui-color-indigo" type="submit">
#             UPLOAD
#           </button>
#         </form>
#
#
# <div class="mdui-card mdui-m-y-2">
#     <div class="mdui-card-menu">
#         <button class="mdui-btn mdui-btn-icon mdui-text-color-theme-accent">
#             <i class="mdui-icon material-icons">check</i>
#         </button>
#     </div>
#     <!-- 卡片的标题和副标题 -->
#     <div class="mdui-card-primary">
#         <div class="mdui-card-primary-title mdui-text-color-red-700">demo</div>
#         <div class="mdui-card-primary-subtitle">2022-10-04 20:02:42.699871</div>
#     </div>
#     <!-- 卡片的内容 -->
#     <div class="mdui-card-content">
#
#         <div class="mdui-chip">
#             <span class="mdui-chip-icon mdui-color-orange">
#                 <i class="mdui-icon material-icons">error_outline</i>
#             </span>
#             <span class="mdui-chip-title">WARNING : 4</span>
#         </div>
#         <div class="mdui-chip">
#             <span class="mdui-chip-icon mdui-color-indigo">
#                 <i class="mdui-icon material-icons">code</i>
#             </span>
#             <span class="mdui-chip-title">API : 4</span>
#         </div>
#     </div>
#     <!-- 卡片的按钮 -->
#     <div class="mdui-card-actions mdui-float-right">
#         <a class="mdui-btn mdui-ripple" href="/e/report?id=1"  >REPORT</a>
#     </div>
# </div>
#
#
#
#       </div>
#       <div class="mdui-col-md-4 mdui-col-sm-2 mdui-m-t-5 mdui-hidden-sm-down">
#         <div class="mdui-card">
#           <div class="mdui-card-menu">
#             <button class="mdui-btn mdui-btn-icon mdui-text-color-theme-accent">
#               <i class="mdui-icon material-icons">close</i>
#             </button>
#           </div>
#           <div class="mdui-card-primary">
#             <div class="mdui-typo-title">Notice</div>
#             <div class="mdui-typo-caption">Boost your security test</div>
#             <hr>
#             <div class="mdui-typo-headline mdui-text-color-indigo"></div>
#           </div>
#         </div>
#       </div>
#
#     </div>
#   </main>
#
#
#   <script src="https://unpkg.com/mdui@1.0.2/dist/js/mdui.min.js"></script>
#   <script src="/static/jquery.js"></script>
#   <script>
#     $SCRIPT_ROOT = "";
#   </script>
#   <script src="/static/dashboard.js"></script>
# </body>
#
# </html>

# %%
# logout

url = base_url + "u/logout"
response = current_session.post(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="https://unpkg.com/mvp.css@1.10.2/mvp.css">
#     <title>Login</title>
# </head>
#
# <body>
#     <main>
#         <section>
#             <form action="/u/login"  method="post">
#                 <header>
#                     <h1>SecCloud Login</h1>
#                 </header>
#                 <label for="input1">Username:</label>
#                 <input type="text" id="name" name="username" size="20" placeholder="User">
#                 <label for="textarea1">Password:</label>
#                 <input type="text" id="password" name="password" size="20" placeholder="********">
#                 <center>
#                     <p>Logout success</p>
#                     <button type="submit">Submit</button>
#                 </center>
#             </form>
#         </section>
#     </main>
# </body>
#
# </html>
